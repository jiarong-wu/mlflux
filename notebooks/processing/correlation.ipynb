# %%
import numpy as np
import xarray as xr
from matplotlib import pyplot as plt

# %%
psd = xr.load_dataset('../../data/Processed/psd_wave.nc')

# %%
psd
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 10073)
# Coordinates:
#   * time     (time) datetime64[ns] 1996-12-22T19:00:00.288000 ... 2016-04-13T...
# Data variables: (12/26)
#     taucx    (time) float64 0.1895 0.6395 0.3934 ... 0.07723 0.07373 0.08168
#     taucy    (time) float64 0.0333 0.1182 -0.023 ... -0.06492 -0.02255 -0.0589
#     hsc      (time) float64 -29.54 -100.4 -60.81 -142.7 ... -5.808 1.075 -13.14
#     hlc      (time) float64 -99.11 -180.2 -153.9 -218.3 ... -39.32 -43.95 -109.2
#     U        (time) float64 12.14 16.7 16.75 17.0 ... 9.779 8.903 8.239 8.543
#     tsea     (time) float64 7.569 11.82 11.86 11.91 ... 11.43 10.9 11.38 12.66
#     ...       ...
#     plp0     (time) float64 35.55 111.3 111.7 112.0 112.3 ... 0.0 0.0 0.0 0.0
#     pdir0    (time) float64 39.06 72.15 72.69 73.58 74.38 ... 0.0 0.0 0.0 0.0
#     phs1     (time) float64 0.121 0.6146 0.5992 0.5875 ... 3.759 3.677 3.366
#     plp1     (time) float64 90.67 162.9 162.3 161.2 ... 378.4 363.1 356.7 343.2
# ...

# %%
# metz = psd.where(psd.pcode==77,drop=True)
gasex = psd.where(psd.pcode==71,drop=True)

# %%
a = (gasex.time.isel(time=1) - gasex.time.isel(time=0))
b = a.astype('datetime64[ns]')
print(b / np.timedelta64(1, 'm'))
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[46], line 3
#       1 a = (gasex.time.isel(time=1) - gasex.time.isel(time=0))
#       2 b = a.astype('datetime64[ns]')
# ----> 3 print(b / np.timedelta64(1, 'm'))
#
# File /ext3/miniconda3/lib/python3.11/site-packages/xarray/core/_typed_ops.py:234, in DataArrayOpsMixin.__truediv__(self, other)
#     233 def __truediv__(self, other):
# --> 234     return self._binary_op(other, operator.truediv)
#
# File /ext3/miniconda3/lib/python3.11/site-packages/xarray/core/dataarray.py:4620, in DataArray._binary_op(self, other, f, reflexive)
#    4616 other_variable = getattr(other, "variable", other)
#    4617 other_coords = getattr(other, "coords", None)
#    4619 variable = (
# -> 4620     f(self.variable, other_variable)
#    4621     if not reflexive
#    4622     else f(other_variable, self.variable)
#    4623 )
# ...

# %%
gasex.time.diff(dim='time').plot()

# %%
gasex.lat.plot(marker='.')
gasex.lon.plot(marker='.')

# %%
metz.lat.diff('time').plot(marker='.')
# metz.lon.differentiate('time').plot()
# plt.ylim([-0.1,0.1])

# %%
metz.lon.plot()
