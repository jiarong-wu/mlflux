# %%
import h5py
import scipy.io as sio
from matplotlib import pyplot as plt

# %%
datapath = '/Users/jwu/Work/Code/mlflux/data/Zippel/zippel2024.mat'

# %%
with h5py.File(datapath, "r") as f:
    group = f["/mNode_20m"]
    print(list(group.keys()))   # list fields
    RH = group["met_RH"][:]
    T = group["met_temp"][:]
    zq = group["met_z"][:]
# Out:
# ['B', 'Co_uw20Hz_s1', 'Co_uw20Hz_s2', 'Co_uw20Hz_s3', 'Hs', 'Ppp1', 'Ppp2', 'Ppp3', 'Ppp_20Hz_p1', 'Ppp_20Hz_p2', 'Ppp_20Hz_p3', 'Puu20Hz_s1', 'Puu20Hz_s2', 'Puu20Hz_s3', 'Pww1', 'Pww2', 'Pww20Hz_s1', 'Pww20Hz_s2', 'Pww20Hz_s3', 'Pww3', 'Pww4', 'Te', 'Tp', 'Ts_bar', 'Tsw_bar', 'alpha', 'avg_return_rate', 'beta', 'epsilon', 'etap_cpsd1', 'etap_cpsd2', 'etap_cpsd3', 'etap_freq1', 'etap_freq2', 'etap_freq3', 'etap_msc1', 'etap_msc2', 'etap_msc3', 'etau_cpsd1', 'etau_cpsd2', 'etau_cpsd3', 'etau_freq1', 'etau_freq2', 'etau_freq3', 'etau_msc1', 'etau_msc2', 'etau_msc3', 'etaw_cpsd1', 'etaw_cpsd2', 'etaw_cpsd3', 'etaw_freq1', 'etaw_freq2', 'etaw_freq3', 'etaw_msc1', 'etaw_msc2', 'etaw_msc3', 'f20Hz_p1', 'f20Hz_p2', 'f20Hz_p3', 'f20Hz_s1', 'f20Hz_s2', 'f20Hz_s3', 'freq_p1', 'freq_p2', 'freq_p3', 'freq_s1', 'freq_s2', 'freq_s3', 'freq_s4', 'length_eta', 'mday', 'met_LW_down', 'met_Pair', 'met_RH', 'met_SW', 'met_level_above_tower_base', 'met_temp', 'met_z', 'paros_Pair', 'pw1', 'pw2', 'pw3', 
# ...

# %%
plt.plot(RH[:,0])
plt.plot(RH[:,1])

# %%
plt.plot(T[:,0])
plt.plot(T[:,1])

# %%
plt.plot(zq[:,0])
plt.plot(zq[:,1])
plt.ylim([-10, 20])
# Out:
# (-10.0, 20.0)
